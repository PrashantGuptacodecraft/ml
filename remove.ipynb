# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv("data_science_job.csv")
# df.head()
# print(df.head())
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
cols=[var for var in df.columns if df[var].isnull().mean()<0.05 and df[var].isnull().mean()>0]
cols
# Out:
# ['city_development_index',
#  'enrolled_university',
#  'education_level',
#  'experience',
#  'training_hours']

# %%
df[cols].sample(5)
# Out:
#        city_development_index enrolled_university education_level  experience  \
# 2928                     0.91       no_enrollment         Masters         3.0
# 10673                    0.91       no_enrollment     High School        20.0
# 6015                     0.55       no_enrollment        Graduate        17.0
# 3043                     0.92       no_enrollment        Graduate         0.0
# 14206                    0.92       no_enrollment         Masters        18.0
#
#        training_hours
# 2928            248.0
# 10673            77.0
# 6015             13.0
# 3043             50.0
# 14206            58.0

# %%
df['education_level'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0              Graduate
# 1              Graduate
# 2              Graduate
# 3              Graduate
# 4               Masters
#               ...
# 19153          Graduate
# 19154          Graduate
# 19155          Graduate
# 19156       High School
# 19157    Primary School
# Name: education_level, Length: 19158, dtype: str>

# %%
len(df[cols].dropna()) / len(df)
# Out:
# 0.8968577095730244

# %%
new_df=df[cols].dropna()
df.shape,new_df.shape
# Out:
# ((19158, 13), (17182, 5))

# %%
new_df.hist(bins=50,density=True,figsize=(12,12))
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
#original data
df['training_hours'].hist(bins=50,density=True,ax=ax,color='red')
new_df['training_hours'].hist(bins=50,ax=ax,density=True,alpha=0.8)
# Out:
# <Axes: >

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
df['training_hours'].plot.density(color='red')
new_df['training_hours'].plot.density(color='green')
# Out:
# <Axes: ylabel='Density'>
